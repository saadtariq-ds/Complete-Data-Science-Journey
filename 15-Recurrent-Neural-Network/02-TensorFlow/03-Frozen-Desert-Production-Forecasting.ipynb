# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, LSTM
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading Dataset

# %%
df = pd.read_csv('Frozen_Dessert_Production.csv', parse_dates=True, index_col='DATE')
df.head()
# Out:
#             IPN31152N
# DATE
# 1972-01-01    59.9622
# 1972-02-01    67.0605
# 1972-03-01    74.2350
# 1972-04-01    78.1120
# 1972-05-01    84.7636

# %%
df.columns = ['Production']
df.head()
# Out:
#             Production
# DATE
# 1972-01-01     59.9622
# 1972-02-01     67.0605
# 1972-03-01     74.2350
# 1972-04-01     78.1120
# 1972-05-01     84.7636

# %%
df.tail()
# Out:
#             Production
# DATE
# 2019-05-01    114.5613
# 2019-06-01    124.9605
# 2019-07-01    110.2632
# 2019-08-01    102.6085
# 2019-09-01    101.5866

# %%
df.plot(figsize=(12,8));

# %% [markdown]
# ## Train Test Split

# %%
len(df)
# Out:
# 573

# %%
len(df) - 24
# Out:
# 549

# %%
test_size = 24
test_index = len(df) - test_size

# %%
train_set = df.iloc[:test_index]
test_set = df.iloc[test_index:]

# %%
len(test_set)
# Out:
# 24

# %% [markdown]
# ## Normalization

# %%
scaler = MinMaxScaler()

# %%
train_set_scaled = scaler.fit_transform(train_set)
test_set_scaled = scaler.transform(test_set)

# %% [markdown]
# ## Time Series Generator

# %%
len(test_set)
# Out:
# 24

# %%
length = 18
batch_size = 1

generator = TimeseriesGenerator(
    data=train_set_scaled,
    targets=train_set_scaled,
    length=length,
    batch_size=batch_size
)

# %%
len(train_set_scaled)
# Out:
# 549

# %%
len(generator)
# Out:
# 531

# %%
X, y = generator[0]

# %%
X
# Out:
# array([[[0.00947104],
#         [0.06108982],
#         [0.11326273],
#         [0.14145625],
#         [0.18982663],
#         [0.30495972],
#         [0.30154406],
#         [0.27416065],
#         [0.19736841],
#         [0.08532665],
#         [0.01561588],
#         [0.        ],
#         [0.01774221],
#         [0.09850931],
#         [0.15590133],
#         [0.18358944],
#         [0.20878908],
#         [0.37150354]]])

# %%
y
# Out:
# array([[0.3542551]])

# %%
train_set_scaled
# Out:
# array([[0.00947104],
#        [0.06108982],
#        [0.11326273],
#        [0.14145625],
#        [0.18982663],
#        [0.30495972],
#        [0.30154406],
#        [0.27416065],
#        [0.19736841],
#        [0.08532665],
#        [0.01561588],
#        [0.        ],
#        [0.01774221],
#        [0.09850931],
#        [0.15590133],
#        [0.18358944],
#        [0.20878908],
#        [0.37150354],
#        [0.3542551 ],
#        [0.29817568],
#        [0.23973867],
#        [0.12104304],
#        [0.05289938],
#        [0.02087498],
#        [0.03141355],
#        [0.12133246],
#        [0.18622481],
#        [0.18855185],
#        [0.23182893],
#        [0.37263651],
#        [0.32891584],
#        [0.30809031],
#        [0.22409662],
#        [0.10933731],
#        [0.05452176],
#        [0.01749278],
#        [0.04076752],
#        [0.12186114],
#        [0.19277469],
#        [0.19221257],
#        [0.28139264],
#        [0.39898221],
#        [0.35985962],
#        [0.3357137 ],
#        [0.22874706],
#        [0.12405219],
#        [0.08404241],
#        [0.02969736],
#        [0.02386668],
#        [0.11198795],
#        [0.20583228],
#        [0.22885832],
#        [0.258115  ],
#        [0.37353242],
#        [0.35488703],
#        [0.32839226],
#        [0.24418041],
#        [0.11957773],
#        [0.06451857],
#        [0.02780228],
#        [0.0371497 ],
#        [0.11927158],
#        [0.22805913],
#        [0.24728191],
#        [0.29422626],
#        [0.40769115],
#        [0.39028709],
#        [0.34726599],
#        [0.24042588],
#        [0.12627596],
#        [0.06351285],
#        [0.0202285 ],
#        [0.02347545],
#        [0.10334519],
#        [0.1837756 ],
#        [0.2210642 ],
#        [0.24573807],
#        [0.38298674],
#        [0.35098488],
#        [0.32746581],
#        [0.23241214],
#        [0.14925109],
#        [0.06708485],
#        [0.02722198],
#        [0.03164989],
#        [0.11112186],
#        [0.2019265 ],
#        [0.23665099],
#        [0.26208914],
#        [0.37409745],
#        [0.35265235],
#        [0.34987663],
#        [0.26656578],
#        [0.15226024],
#        [0.06714158],
#        [0.03363442],
#        [0.06052406],
#        [0.12932729],
#        [0.19801489],
#        [0.21334643],
#        [0.24370918],
#        [0.36219466],
#        [0.35788891],
#        [0.35776456],
#        [0.23277138],
#        [0.12775799],
#        [0.05691861],
#        [0.03785508],
#        [0.01381533],
#        [0.12962762],
#        [0.20328854],
#        [0.22088022],
#        [0.25480042],
#        [0.37831666],
#        [0.37904459],
#        [0.34512729],
#        [0.23860352],
#        [0.13282148],
#        [0.08994218],
#        [0.05773525],
#        [0.02483822],
#        [0.13358431],
#        [0.21702097],
#        [0.20059209],
#        [0.25218323],
#        [0.35104815],
#        [0.30896077],
#        [0.2875462 ],
#        [0.20017176],
#        [0.0975465 ],
#        [0.05358004],
#        [0.02042848],
#        [0.03538915],
#        [0.11420518],
#        [0.20355324],
#        [0.18085953],
#        [0.25954903],
#        [0.37499118],
#        [0.35553497],
#        [0.3391439 ],
#        [0.27074427],
#        [0.148385  ],
#        [0.08505031],
#        [0.05037236],
#        [0.06065787],
#        [0.19601364],
#        [0.27717707],
#        [0.31389336],
#        [0.36123257],
#        [0.5103535 ],
#        [0.48335114],
#        [0.42139813],
#        [0.35071873],
#        [0.21527206],
#        [0.15798912],
#        [0.11136474],
#        [0.12736022],
#        [0.20326527],
#        [0.30960943],
#        [0.33601549],
#        [0.40474599],
#        [0.52313039],
#        [0.47891086],
#        [0.42749206],
#        [0.33018917],
#        [0.20046264],
#        [0.11634751],
#        [0.08706829],
#        [0.10924132],
#        [0.22016465],
#        [0.30084013],
#        [0.33190536],
#        [0.39731693],
#        [0.4993168 ],
#        [0.4556863 ],
#        [0.43936795],
#        [0.27786718],
#        [0.20181378],
#        [0.13316399],
#        [0.08697739],
#        [0.11117567],
#        [0.2609009 ],
#        [0.32682078],
#        [0.35021332],
#        [0.42287143],
#        [0.53338753],
#        [0.49991019],
#        [0.47278857],
#        [0.34951085],
#        [0.22357085],
#        [0.18885364],
#        [0.15302162],
#        [0.15446002],
#        [0.28620889],
#        [0.41037451],
#        [0.44149937],
#        [0.51908643],
#        [0.67098671],
#        [0.6310693 ],
#        [0.59691057],
#        [0.42703174],
#        [0.30134117],
#        [0.21173496],
#        [0.17769331],
#        [0.21058162],
#        [0.33226023],
#        [0.41286154],
#        [0.45465949],
#        [0.49043479],
#        [0.5949195 ],
#        [0.55552639],
#        [0.50626082],
#        [0.37695462],
#        [0.28191477],
#        [0.23327315],
#        [0.19892025],
#        [0.17357736],
#        [0.32809629],
#        [0.4263489 ],
#        [0.46025165],
#        [0.4935632 ],
#        [0.60079527],
#        [0.617843  ],
#        [0.51202315],
#        [0.40538302],
#        [0.28864864],
#        [0.21277195],
#        [0.19688192],
#        [0.19348371],
#        [0.33595876],
#        [0.4323352 ],
#        [0.46814249],
#        [0.50374908],
#        [0.71868953],
#        [0.59645534],
#        [0.56009611],
#        [0.45327491],
#        [0.32803084],
#        [0.24159158],
#        [0.22064751],
#        [0.22953752],
#        [0.37632559],
#        [0.52945048],
#        [0.55670736],
#        [0.61181451],
#        [0.72450058],
#        [0.64286447],
#        [0.62011695],
#        [0.49738245],
#        [0.36981643],
#        [0.29573592],
#        [0.24950569],
#        [0.26693083],
#        [0.47106438],
#        [0.54508017],
#        [0.59702983],
#        [0.66830844],
#        [0.77390504],
#        [0.7325754 ],
#        [0.6803734 ],
#        [0.50636554],
#        [0.37017931],
#        [0.2737985 ],
#        [0.23159986],
#        [0.29683036],
#        [0.44392749],
#        [0.54969425],
#        [0.60065928],
#        [0.62634759],
#        [0.73133116],
#        [0.70677655],
#        [0.61726342],
#        [0.45562739],
#        [0.37282413],
#        [0.31570409],
#        [0.25793611],
#        [0.33661906],
#        [0.46491009],
#        [0.58333448],
#        [0.66460627],
#        [0.65484071],
#        [0.84212141],
#        [0.83159666],
#        [0.77134312],
#        [0.5765359 ],
#        [0.49703412],
#        [0.35935495],
#        [0.26985999],
#        [0.36437626],
#        [0.51454071],
#        [0.63086641],
#        [0.67844487],
#        [0.7149939 ],
#        [0.91226778],
#        [0.80510188],
#        [0.68516274],
#        [0.56400117],
#        [0.39649446],
#        [0.2818566 ],
#        [0.26014025],
#        [0.32665061],
#        [0.49801438],
#        [0.57758088],
#        [0.57365619],
#        [0.60384732],
#        [0.72545175],
#        [0.63770353],
#        [0.573702  ],
#        [0.42061493],
#        [0.34058739],
#        [0.26069946],
#        [0.18097152],
#        [0.2756834 ],
#        [0.43318312],
#        [0.51407385],
#        [0.55039963],
#        [0.595334  ],
#        [0.65870359],
#        [0.58609057],
#        [0.51790837],
#        [0.40765115],
#        [0.27578448],
#        [0.17157466],
#        [0.14559837],
#        [0.20169161],
#        [0.30520478],
#        [0.34726308],
#        [0.39276975],
#        [0.4190151 ],
#        [0.51046112],
#        [0.46158897],
#        [0.44354134],
#        [0.32636192],
#        [0.24344375],
#        [0.1867324 ],
#        [0.1517403 ],
#        [0.25227413],
#        [0.3827584 ],
#        [0.482933  ],
#        [0.5663013 ],
#        [0.5595318 ],
#        [0.66509713],
#        [0.63101039],
#        [0.53208803],
#        [0.42556207],
#        [0.40049988],
#        [0.24705066],
#        [0.21710605],
#        [0.3106246 ],
#        [0.41679205],
#        [0.4655653 ],
#        [0.55069633],
#        [0.53323628],
#        [0.65273256],
#        [0.6022453 ],
#        [0.55351132],
#        [0.50874712],
#        [0.41053159],
#        [0.3376495 ],
#        [0.33408986],
#        [0.45304729],
#        [0.61827568],
#        [0.70208393],
#        [0.80395291],
#        [0.7747675 ],
#        [0.94670357],
#        [0.83318341],
#        [0.76047149],
#        [0.66868586],
#        [0.56791495],
#        [0.40647818],
#        [0.34147893],
#        [0.48424123],
#        [0.60888972],
#        [0.62540223],
#        [0.67443146],
#        [0.64487663],
#        [0.75766377],
#        [0.63589572],
#        [0.59974083],
#        [0.49501178],
#        [0.41579651],
#        [0.34921415],
#        [0.25354891],
#        [0.33055422],
#        [0.48986321],
#        [0.59474788],
#        [0.65434403],
#        [0.66753543],
#        [0.80265631],
#        [0.71705115],
#        [0.68986262],
#        [0.62369695],
#        [0.58805692],
#        [0.44984325],
#        [0.38266895],
#        [0.52076263],
#        [0.65111818],
#        [0.73167294],
#        [0.82298299],
#        [0.80931746],
#        [1.        ],
#        [0.95692363],
#        [0.87718478],
#        [0.69141447],
#        [0.62214002],
#        [0.4621831 ],
#        [0.3511725 ],
#        [0.52481749],
#        [0.62277559],
#        [0.71054126],
#        [0.79313728],
#        [0.73648118],
#        [0.90148196],
#        [0.85356971],
#        [0.76810199],
#        [0.63817985],
#        [0.50364654],
#        [0.38121819],
#        [0.31740064],
#        [0.49162376],
#        [0.58495105],
#        [0.68667095],
#        [0.80952762],
#        [0.79009104],
#        [0.88302055],
#        [0.78941838],
#        [0.65857997],
#        [0.60582894],
#        [0.49204408],
#        [0.32987647],
#        [0.2969518 ],
#        [0.35876955],
#        [0.48110555],
#        [0.59006762],
#        [0.60473814],
#        [0.61824732],
#        [0.80533386],
#        [0.62801433],
#        [0.58998181],
#        [0.47530395],
#        [0.36576521],
#        [0.3184129 ],
#        [0.18278007],
#        [0.25838552],
#        [0.41127697],
#        [0.51611292],
#        [0.54115039],
#        [0.57690677],
#        [0.66681259],
#        [0.55138499],
#        [0.53718642],
#        [0.4420215 ],
#        [0.34988681],
#        [0.21230072],
#        [0.13914302],
#        [0.23728292],
#        [0.37697716],
#        [0.49767551],
#        [0.53803288],
#        [0.55192821],
#        [0.62024348],
#        [0.51047058],
#        [0.48647082],
#        [0.41747634],
#        [0.28427817],
#        [0.16309115],
#        [0.10268271],
#        [0.24689286],
#        [0.3454618 ],
#        [0.40423986],
#        [0.42151084],
#        [0.41797011],
#        [0.45169179],
#        [0.41887911],
#        [0.40972803],
#        [0.31339595],
#        [0.23591506],
#        [0.12980579],
#        [0.09307932],
#        [0.19444507],
#        [0.29743684],
#        [0.39142952],
#        [0.40833181],
#        [0.40654945],
#        [0.47764626],
#        [0.39026746],
#        [0.35620545],
#        [0.27422828],
#        [0.2198076 ],
#        [0.11764411],
#        [0.07351475],
#        [0.14149624],
#        [0.2863296 ],
#        [0.35795581],
#        [0.35814561],
#        [0.37998486],
#        [0.50926561],
#        [0.39057433],
#        [0.34465461],
#        [0.28747203],
#        [0.23516459],
#        [0.15569044],
#        [0.06649001],
#        [0.20170834],
#        [0.31321197],
#        [0.40080166],
#        [0.44136265],
#        [0.42156466],
#        [0.52634606],
#        [0.42622818],
#        [0.38365722],
#        [0.30511534],
#        [0.23707931],
#        [0.20297948],
#        [0.12155208],
#        [0.19574094],
#        [0.30468338],
#        [0.37028329],
#        [0.36143183],
#        [0.34467716],
#        [0.41797884],
#        [0.36154745],
#        [0.38938173],
#        [0.30315844],
#        [0.25649698],
#        [0.19782873],
#        [0.13318726],
#        [0.24834362],
#        [0.3149827 ],
#        [0.41828135],
#        [0.4766849 ],
#        [0.45728977],
#        [0.54050318],
#        [0.48134479],
#        [0.45575247],
#        [0.35906261],
#        [0.31068714],
#        [0.20365141],
#        [0.16432593],
#        [0.2587782 ],
#        [0.39071032],
#        [0.44387077],
#        [0.4695409 ],
#        [0.41743926],
#        [0.46851409],
#        [0.41889656],
#        [0.39641011],
#        [0.28544533]])

# %% [markdown]
# ## Creating the Model

# %%
num_of_features = 1

# %%
model = Sequential()

model.add(LSTM(units=150 , activation='relu', input_shape=(length, num_of_features)))
model.add(Dense(units=1))

model.compile(
    optimizer='adam',
    loss='mse'
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 150)            │        91,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           151 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 91,351 (356.84 KB)
#  Trainable params: 91,351 (356.84 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training the Model

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=2
)

# %%
length = 18
batch_size = 1

# %%
validation_generator = TimeseriesGenerator(
    data=test_set_scaled,
    targets=test_set_scaled,
    length=length,
    batch_size=batch_size
)

# %%
model.fit(
    generator,
    validation_data=validation_generator,
    epochs=20,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0393 - val_loss: 0.0080
# Epoch 2/20
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0116 - val_loss: 0.0019
# Epoch 3/20
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 4/20
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0042 - val_loss: 0.0018
# Epoch 5/20
# 531/531 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0028 - val_loss: 0.0017

# %%
losses = pd.DataFrame(model.history.history)
losses.plot();

# %% [markdown]
# ## Evaluation on Test Data

# %%
test_predictions = []

first_eval_batch = train_set_scaled[-length:]
current_batch = first_eval_batch.reshape((1, length, num_of_features))

for i in range(len(test_set)):
    current_prediction = model.predict(current_batch)[0]
    test_predictions.append(current_prediction)
    current_batch = np.append(current_batch[:,1:,:], [[current_prediction]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
true_predictions = scaler.inverse_transform(test_predictions)
test_set['Predictions'] = true_predictions
test_set.plot(figsize=(12,8));

# %% [markdown]
# ## Calculate RMSE

# %%
np.sqrt(mean_squared_error(test_set['Production'], test_set['Predictions']))
# Out:
# 12.446026473586164

# %% [markdown]
# ## Forecast into Unknown Future

# %%
full_scaler = MinMaxScaler()
scaled_full_data = full_scaler.fit_transform(df)

# %%
length = 18
batch_size = 1

# %%
generator = TimeseriesGenerator(
    data=scaled_full_data,
    targets=scaled_full_data,
    length=length,
    batch_size=batch_size
)

# %%
num_of_features = 1

# %%
model = Sequential()

model.add(LSTM(units=150 , activation='relu', input_shape=(length, num_of_features)))
model.add(Dense(units=1))

model.compile(
    optimizer='adam',
    loss='mse'
)

# %%
model.fit(
    generator,
    epochs=8,
)
# Out:
# Epoch 1/8
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0369
# Epoch 2/8
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0137
# Epoch 3/8
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0035
# Epoch 4/8
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0029
# Epoch 5/8
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0028
# Epoch 6/8
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0034
# Epoch 7/8
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0026
# Epoch 8/8
# 555/555 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027

# %%
forecast = []
periods = 12

first_eval_batch = scaled_full_data[-length:]
current_batch = first_eval_batch.reshape((1, length, num_of_features))

for i in range(periods):
    current_prediction = model.predict(current_batch)[0]
    forecast.append(current_prediction)
    current_batch = np.append(current_batch[:,1:,:], [[current_prediction]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
forecast = full_scaler.inverse_transform(forecast)

# %%
df
# Out:
#             Production
# DATE
# 1972-01-01     59.9622
# 1972-02-01     67.0605
# 1972-03-01     74.2350
# 1972-04-01     78.1120
# 1972-05-01     84.7636
# ...                ...
# 2019-05-01    114.5613
# 2019-06-01    124.9605
# 2019-07-01    110.2632
# 2019-08-01    102.6085
# 2019-09-01    101.5866
#
# [573 rows x 1 columns]

# %%
forecast
# Out:
# array([[ 86.82042682],
#        [ 80.99265055],
#        [ 83.37961137],
#        [ 94.53301554],
#        [106.4242042 ],
#        [115.06619853],
#        [121.08768805],
#        [124.03034681],
#        [121.7304714 ],
#        [114.3391637 ],
#        [103.23547111],
#        [ 91.00120497]])

# %%
forecast_index = pd.date_range(
    start='2019-09-02', 
    periods=periods,
    freq="MS"
)

forecast_index
# Out:
# DatetimeIndex(['2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01',
#                '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
forecast_df = pd.DataFrame(
    data=forecast,
    index=forecast_index,
    columns=['Forecast']
)

# %%
df.plot()
forecast_df.plot();

# %%
ax = df.plot()
forecast_df.plot(ax=ax);

# %%
ax = df.plot()
forecast_df.plot(ax=ax)
plt.xlim('2018-01-01', '2020-12-01');

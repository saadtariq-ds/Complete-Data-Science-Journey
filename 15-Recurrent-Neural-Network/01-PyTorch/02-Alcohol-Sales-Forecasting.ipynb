#         6558.,  7481.,  9475.,  9424.,  9351., 10552.,  9077.,  9273.,
#         9420.,  9413.,  9866., 11455.,  6901.,  8014.,  9832.,  9281.,
#         9967., 11344.,  9106., 10469., 10085.,  9612., 10328., 11483.,
#         7486.,  8641.,  9709.,  9423., 11342., 11274.,  9845., 11163.,
#         9532., 10754., 10953., 11922.,  8395.,  8888., 10110., 10493.,
#        12218., 11385., 11186., 11462., 10494., 11540., 11138., 12709.,
#         8557.,  9059., 10055., 10977., 11792., 11904., 10965., 10981.,
#        10828., 11817., 10470., 13310.,  8400.,  9062., 10722., 11107.,
#        11508., 12904., 11869., 11224., 12022., 11983., 11506., 14183.,
#         8648., 10321., 12107., 11420., 12238., 13681., 10950., 12700.,
#        12272., 11905., 13016., 14421.,  9043., 10452., 12481., 11491.,
#        13545., 14730., 11416., 13402., 11907., 12711., 13261., 14265.,
#         9564., 10415., 12683., 11919., 14138., 14583., 12640., 14257.,
#        12396., 13914., 14174., 15504., 10718.])

# %% [markdown]
# ## Setting Training and Test Set Size

# %%
test_size = 12

# %%
train_set = y[:-test_size]
test_set = y[-test_size:]

# %%
test_set
# Out:
# array([10415., 12683., 11919., 14138., 14583., 12640., 14257., 12396.,
#        13914., 14174., 15504., 10718.])

# %% [markdown]
# ## Normalization

# %%
scaler = MinMaxScaler(feature_range=(-1,1))

# %%
train_normalized = scaler.fit_transform(train_set.reshape(-1,1))

# %%
train_normalized.min()
# Out:
# -1.0

# %%
train_normalized.max()
# Out:
# 1.0

# %%
train_normalized.mean()
# Out:
# -0.2041940178388313

# %%
type(train_normalized)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Converting to Tensor

# %%
train_normalized = torch.FloatTensor(train_normalized).view(-1)
train_normalized
# Out:
# tensor([-0.9268, -0.9270, -0.8340, -0.7379, -0.7966, -0.7439, -0.7547, -0.8109,
#         -0.8128, -0.7901, -0.7933, -0.6743, -1.0000, -0.9607, -0.8070, -0.7699,
#         -0.7819, -0.7154, -0.7560, -0.7562, -0.7721, -0.7940, -0.7489, -0.6678,
#         -0.9925, -0.9408, -0.7586, -0.7897, -0.7557, -0.6660, -0.7790, -0.7114,
#         -0.7704, -0.7919, -0.7003, -0.6683, -0.9420, -0.9226, -0.7884, -0.8354,
#         -0.7121, -0.6678, -0.7962, -0.6634, -0.7942, -0.7396, -0.6889, -0.6931,
#         -0.8858, -0.8373, -0.7896, -0.7285, -0.6260, -0.6914, -0.6735, -0.6528,
#         -0.7719, -0.6613, -0.6890, -0.6468, -0.8757, -0.8643, -0.7567, -0.7258,
#         -0.6275, -0.6536, -0.6239, -0.6576, -0.6685, -0.6049, -0.6923, -0.4984,
#         -0.8692, -0.8311, -0.6808, -0.6480, -0.6229, -0.5870, -0.5890, -0.6451,
#         -0.5753, -0.5637, -0.6042, -0.4435, -0.8289, -0.7600, -0.5815, -0.5808,
#         -0.5630, -0.4623, -0.5572, -0.5114, -0.5218, -0.5182, -0.4617, -0.3606,
#         -0.7928, -0.6716, -0.4911, -0.6030, -0.4181, -0.3774, -0.5547, -0.3847,
#         -0.5118, -0.4374, -0.4035, -0.3765, -0.6494, -0.6265, -0.5107, -0.5106,
#         -0.3558, -0.3784, -0.4285, -0.3488, -0.5651, -0.3993, -0.3576, -0.2907,
#         -0.6434, -0.5878, -0.4348, -0.4027, -0.2846, -0.3623, -0.3287, -0.3095,
#         -0.4671, -0.3345, -0.3700, -0.1548, -0.6077, -0.5593, -0.4217, -0.3658,
#         -0.2969, -0.2987, -0.2244, -0.2760, -0.3840, -0.2145, -0.3483, -0.0582,
#         -0.5559, -0.5099, -0.3138, -0.3054, -0.2646, -0.1645, -0.2721, -0.2538,
#         -0.2772, -0.2757, -0.1965,  0.0303, -0.5682, -0.4519, -0.1979, -0.2767,
#         -0.1093, -0.0211, -0.2613, -0.0657, -0.1948, -0.2001, -0.1083,  0.0037,
#         -0.4812, -0.3916, -0.1637, -0.2642, -0.0064,  0.0763, -0.1861,  0.0471,
#         -0.1442, -0.0411,  0.0423,  0.1136, -0.3852, -0.3654, -0.1172, -0.1799,
#          0.1179,  0.1032, -0.0466,  0.1133, -0.1295,  0.1314,  0.0871,  0.2025,
#         -0.3056, -0.2389, -0.0881,  0.0025,  0.1562,  0.1875,  0.1150,  0.0845,
#          0.0589,  0.1825, -0.0209,  0.3348, -0.2760, -0.2227, -0.0329,  0.0481,
#          0.0835,  0.2199,  0.1071,  0.0073,  0.0669,  0.0333,  0.0117,  0.3355,
#         -0.3970, -0.2393,  0.1016,  0.0929,  0.0804,  0.2858,  0.0336,  0.0671,
#          0.0922,  0.0910,  0.1685,  0.4401, -0.3384, -0.1481,  0.1627,  0.0685,
#          0.1857,  0.4211,  0.0386,  0.2716,  0.2059,  0.1251,  0.2475,  0.4449,
#         -0.2384, -0.0409,  0.1416,  0.0927,  0.4208,  0.4092,  0.1649,  0.3902,
#          0.1114,  0.3203,  0.3543,  0.5200, -0.0830,  0.0013,  0.2102,  0.2757,
#          0.5706,  0.4282,  0.3941,  0.4413,  0.2758,  0.4547,  0.3859,  0.6545,
#         -0.0553,  0.0305,  0.2008,  0.3584,  0.4977,  0.5169,  0.3564,  0.3591,
#          0.3329,  0.5020,  0.2717,  0.7572, -0.0821,  0.0310,  0.3148,  0.3806,
#          0.4492,  0.6878,  0.5109,  0.4006,  0.5371,  0.5304,  0.4488,  0.9065,
#         -0.0397,  0.2463,  0.5516,  0.4341,  0.5740,  0.8207,  0.3538,  0.6530,
#          0.5798,  0.5171,  0.7070,  0.9472,  0.0278,  0.2687,  0.6155,  0.4463,
#          0.7974,  1.0000,  0.4335,  0.7730,  0.5174,  0.6548,  0.7489,  0.9205,
#          0.1168])

# %% [markdown]
# ## Preparaing Training Sequences

# %%
def input_data(sequence, window_size):
    output = []    # List of tuples
    length_of_sequence = len(sequence)

    for i in range(length_of_sequence - window_size):
        window = sequence[i: i + window_size]
        label = sequence[i + window_size: i + window_size + 1]
        output.append((window, label))

    return output

# %%
window_size = 12

train_data = input_data(
    sequence=train_normalized,
    window_size=window_size
)

# %%
len(train_data)
# Out:
# 301

# %%
325-12-12
# Out:
# 301

# %%
train_data[0]
# Out:
# (tensor([-0.9268, -0.9270, -0.8340, -0.7379, -0.7966, -0.7439, -0.7547, -0.8109,
#          -0.8128, -0.7901, -0.7933, -0.6743]),
#  tensor([-1.]))

# %% [markdown]
# ## Creating LSTM Model

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=100, output_size=1):
        super().__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.linear = nn.Linear(hidden_size, output_size)
        self.hidden = (
            torch.zeros(1,1,hidden_size), 
            torch.zeros(1,1,hidden_size)
        )

    def forward(self, sequence):
        lstm_out, self.hidden = self.lstm(
            sequence.view(len(sequence), 1, -1),
            self.hidden
        )
        prediction = self.linear(lstm_out.view(len(sequence), -1))
        return prediction[-1]

# %%
model = LSTM()
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 100)
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
parameter_list = []
for param in model.parameters():
    parameter_list.append(param.numel())

print(f"Total Number of Parameters: {sum(parameter_list)}")
# Out:
# Total Number of Parameters: 41301

# %% [markdown]
# ## Training the Model

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 100

# %%
start_time = time.time()

for epoch in range(epochs):
    for sequence, y_train in train_data:
        optimizer.zero_grad()
        model.hidden = (
            torch.zeros(1,1,model.hidden_size), 
            torch.zeros(1,1,model.hidden_size)
        )

        y_pred = model(sequence)
        loss = criterion(y_pred, y_train)
        loss.backward()
        optimizer.step()

    print(f"Epoch: {epoch+1} Loss: {loss.item()}")

total_time = time.time() - start_time
print(f"Total Time: {total_time / 60}")
# Out:
# Epoch: 1 Loss: 0.28233852982521057
# Epoch: 2 Loss: 0.327319860458374
# Epoch: 3 Loss: 0.34789469838142395
# Epoch: 4 Loss: 0.3719256520271301
# Epoch: 5 Loss: 0.3151361048221588
# Epoch: 6 Loss: 0.3235134184360504
# Epoch: 7 Loss: 0.3188876509666443
# Epoch: 8 Loss: 0.3237510919570923
# Epoch: 9 Loss: 0.3127082288265228
# Epoch: 10 Loss: 0.3031531870365143
# Epoch: 11 Loss: 0.2995786964893341
# Epoch: 12 Loss: 0.2732376158237457
# Epoch: 13 Loss: 0.28437677025794983
# Epoch: 14 Loss: 0.2864714562892914
# Epoch: 15 Loss: 0.2834108769893646
# Epoch: 16 Loss: 0.26517531275749207
# Epoch: 17 Loss: 0.26962506771087646
# Epoch: 18 Loss: 0.2663728594779968
# Epoch: 19 Loss: 0.2610165774822235
# Epoch: 20 Loss: 0.254077285528183
# Epoch: 21 Loss: 0.2488304078578949
# Epoch: 22 Loss: 0.259377121925354
# Epoch: 23 Loss: 0.24463915824890137
# Epoch: 24 Loss: 0.23362129926681519
# Epoch: 25 Loss: 0.21397297084331512
# Epoch: 26 Loss: 0.19877418875694275
# Epoch: 27 Loss: 0.1647939831018448
# Epoch: 28 Loss: 0.00327340723015368
# Epoch: 29 Loss: 0.017668534070253372
# Epoch: 30 Loss: 0.0075037116184830666
# Epoch: 31 Loss: 8.169341163011268e-05
# Epoch: 94 Loss: 0.0008086051093414426
# Epoch: 95 Loss: 3.941366958315484e-05
# Epoch: 96 Loss: 0.006029067095369101
# Epoch: 97 Loss: 0.00098266894929111
# Epoch: 98 Loss: 0.007823224179446697
# Epoch: 99 Loss: 0.0001875842863228172
# Epoch: 100 Loss: 0.0012936689890921116
# Total Time: 0.4852463920911153

# %% [markdown]
# ## Invert the normalization

# %%
future_forecast = 12

# %%
preds = train_normalized[-window_size:].tolist()

model.eval()

for forecast in range(future_forecast):
    sequence = torch.FloatTensor(preds[-window_size:])

    with torch.no_grad():
        model.hidden = (
            torch.zeros(1,1,model.hidden_size), 
            torch.zeros(1,1,model.hidden_size)
        )

        preds.append(model(sequence).item())

# %%
preds[window_size:]
# Out:
# [0.340773344039917,
#  0.7071198225021362,
#  0.5030633211135864,
#  0.8342243432998657,
#  0.7397944331169128,
#  0.42011934518814087,
#  0.5649489760398865,
#  0.6467539072036743,
#  0.6620506048202515,
#  0.7982387542724609,
#  0.6135746836662292,
#  0.1501433551311493]

# %%
true_predictions = scaler.inverse_transform(
    np.array(preds[window_size:]).reshape(-1,1)
)

true_predictions
# Out:
# array([[10873.85367596],
#        [13016.79740173],
#        [11823.16889685],
#        [13760.29529613],
#        [13207.92753652],
#        [11337.98810968],
#        [12185.16903535],
#        [12663.68698019],
#        [12753.1650129 ],
#        [13549.79759312],
#        [12469.60511211],
#        [ 9758.76355584]])

# %%
df['S4248SM144NCEN'][-12:]
# Out:
# DATE
# 2018-02-01    10415
# 2018-03-01    12683
# 2018-04-01    11919
# 2018-05-01    14138
# 2018-06-01    14583
# 2018-07-01    12640
# 2018-08-01    14257
# 2018-09-01    12396
# 2018-10-01    13914
# 2018-11-01    14174
# 2018-12-01    15504
# 2019-01-01    10718
# Name: S4248SM144NCEN, dtype: int64

# %% [markdown]
# ## Plot the Results

# %%
x = np.arange('2018-02-01', '2019-02-01', dtype="datetime64[M]")
x
# Out:
# array(['2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07',
#        '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01'],
#       dtype='datetime64[M]')

# %%
plt.figure(figsize=(12,4))
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df['S4248SM144NCEN'])
plt.plot(x,true_predictions)
plt.title('Beer, Wine, and Alcohol Sales')
plt.ylabel('Sales (millions of dollars)');

# %%
fig = plt.figure(figsize=(12,4))
plt.grid(True)
plt.autoscale(axis='x',tight=True)
fig.autofmt_xdate()
plt.plot(df['S4248SM144NCEN']['2017-01-01':])
plt.plot(x,true_predictions)
plt.title('Beer, Wine, and Alcohol Sales')
plt.ylabel('Sales (millions of dollars)');

# %% [markdown]
# ## Forecast into an unknown future

# %%
epochs = 100

# %%
# set model to back to training mode
model.train()
# Out:
# LSTM(
#   (lstm): LSTM(1, 100)
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
y_norm = scaler.fit_transform(y.reshape(-1, 1))
y_norm = torch.FloatTensor(y_norm).view(-1)
all_data = input_data(y_norm,window_size)

# %%
start_time = time.time()

for epoch in range(epochs):
    for sequence, y_train in all_data:
        optimizer.zero_grad()
        model.hidden = (
            torch.zeros(1,1,model.hidden_size), 
            torch.zeros(1,1,model.hidden_size)
        )

        y_pred = model(sequence)
        loss = criterion(y_pred, y_train)
        loss.backward()
        optimizer.step
# Epoch: 59 Loss: 0.0007844805368222296
# Epoch: 60 Loss: 0.00522003136575222
# Epoch: 61 Loss: 0.001594632281921804
# Epoch: 62 Loss: 0.0017998950788751245
# Epoch: 63 Loss: 5.616404905595118e-06
# Epoch: 64 Loss: 1.7297310478170402e-05
# Epoch: 65 Loss: 0.0019941471982747316
# Epoch: 66 Loss: 0.0007834166754037142
# Epoch: 67 Loss: 0.0003256002673879266
# Epoch: 68 Loss: 1.0711718459788244e-05
# Epoch: 69 Loss: 3.552234193193726e-05
# Epoch: 70 Loss: 0.0001306952181039378
# Epoch: 71 Loss: 0.000561381340958178
# Epoch: 72 Loss: 0.004557858686894178
# Epoch: 73 Loss: 0.003258664160966873
# Epoch: 74 Loss: 0.0035228291526436806
# Epoch: 75 Loss: 0.0018638847395777702
# Epoch: 76 Loss: 0.02948899194598198
# Epoch: 77 Loss: 0.002805517055094242
# Epoch: 78 Loss: 0.01086441520601511
# Epoch: 79 Loss: 0.012006735429167747
# Epoch: 80 Loss: 0.005812956020236015
# Epoch: 81 Loss: 0.0018071066588163376
# Epoch: 82 Loss: 0.004050658084452152
# Epoch: 83 Loss: 4.457591330719879e-06
# Epoch: 84 Loss: 1.8052409359370358e-05
# Epoch: 85 Loss: 0.0001816921285353601
# Epoch: 86 Loss: 5.9451373090269044e-05
# Epoch: 87 Loss: 0.00024075359397102147
# Epoch: 88 Loss: 0.00020824170496780425
# Epoch: 89 Loss: 0.00034200469963252544
# Epoch: 90 Loss: 0.0019100412027910352
# Epoch: 91 Loss: 0.00497706001624465
# Epoch: 92 Loss: 0.00018953655671793967
# Epoch: 93 Loss: 0.00015456411347258836
# Epoch: 94 Loss: 0.004548803437501192
# Epoch: 95 Loss: 5.8180605265079066e-05
# Epoch: 96 Loss: 0.0003975514555349946
# Epoch: 97 Loss: 7.313619425985962e-05
# Epoch: 98 Loss: 0.0005375414621084929
# Epoch: 99 Loss: 0.0009003013838082552
# Total Time: 0.5036044438680013

# %% [markdown]
# ## Predict Future Values

# %%
window_size = 12
future_forecast = 12

# %%
preds = y[-window_size:].tolist()

for forecast in range(future_forecast):
    sequence = torch.FloatTensor(preds[-window_size:])

    with torch.no_grad():
        model.hidden = (
            torch.zeros(1,1,model.hidden_size), 
            torch.zeros(1,1,model.hidden_size)
        )

        preds.append(model(sequence).item())

# %%
true_predictions = scaler.inverse_transform(np.array(preds).reshape(-1, 1))

# %%
x = np.arange('2019-02-01', '2020-02-01', dtype='datetime64[M]').astype('datetime64[D]')

# %%
plt.figure(figsize=(12,4))
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df['S4248SM144NCEN'])
plt.plot(x,true_predictions[window_size:])
plt.title('Beer, Wine, and Alcohol Sales')
plt.ylabel('Sales (millions of dollars)');

# %%
fig = plt.figure(figsize=(12,4))
plt.grid(True)
plt.autoscale(axis='x',tight=True)
fig.autofmt_xdate()
plt.plot(df['S4248SM144NCEN']['2017-01-01':])
plt.plot(x,true_predictions[window_size:])
plt.title('Beer, Wine, and Alcohol Sales')
plt.ylabel('Sales (millions of dollars)');
